# %%
ball_positions = [
    {1: [100, 150, 110, 160]},  # Frame 1: Ball detected
    {1: [102, 152, 112, 162]},  # Frame 2: Ball detected
    {},                         # Frame 3: Ball not detected (missing)
    {1: [106, 156, 116, 166]},  # Frame 4: Ball detected
]
ball_positions
# Out:
# [{1: [100, 150, 110, 160]},
#  {1: [102, 152, 112, 162]},
#  {},
#  {1: [106, 156, 116, 166]}]

# %%
ball_positions = [x.get(1, []) for x in ball_positions]
ball_positions
# Out:
# [[100, 150, 110, 160], [102, 152, 112, 162], [], [106, 156, 116, 166]]

# %%
import pandas as pd
df_ball_positions = pd.DataFrame(ball_positions, columns=['x1', 'y1', 'x2', 'y2'])
df_ball_positions.head()
# Out:
#       x1     y1     x2     y2
# 0  100.0  150.0  110.0  160.0
# 1  102.0  152.0  112.0  162.0
# 2    NaN    NaN    NaN    NaN
# 3  106.0  156.0  116.0  166.0

# %%
df_ball_positions = df_ball_positions.interpolate()
df_ball_positions = df_ball_positions.bfill() #ensures that any remaining NaN values after interpolation are filled using the next valid detected ball position from subsequent frames. This ensures there are no gaps in the ball positions.
df_ball_positions.head()
# Out:
#       x1     y1     x2     y2
# 0  100.0  150.0  110.0  160.0
# 1  102.0  152.0  112.0  162.0
# 2  104.0  154.0  114.0  164.0
# 3  106.0  156.0  116.0  166.0

# %%
ball_positions = [{1: x} for x in df_ball_positions.to_numpy().tolist()]
ball_positions
# Out:
# [{1: [100.0, 150.0, 110.0, 160.0]},
#  {1: [102.0, 152.0, 112.0, 162.0]},
#  {1: [104.0, 154.0, 114.0, 164.0]},
#  {1: [106.0, 156.0, 116.0, 166.0]}]

# %%
data = {'x1': [100, 102, None, None],
        'y1': [150, 152, None, None],
        'x2': [110, 112, None, None],
        'y2': [160, 162, None, None]}

df = pd.DataFrame(data)
df = df.interpolate()
df = df.bfill()
df.head()
# Out:
#       x1     y1     x2     y2
# 0  100.0  150.0  110.0  160.0
# 1  102.0  152.0  112.0  162.0
# 2  102.0  152.0  112.0  162.0
# 3  102.0  152.0  112.0  162.0
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
a = [{1: [100.0, 150.0, 110.0, 160.0]},
 {1: [102.0, 152.0, 112.0, 162.0]},
 {1: [104.0, 154.0, 114.0, 164.0]},
 {1: [106.0, 156.0, 116.0, 166.0]}]

# %%
s = [{0: [100.0, 150.0, 110.0, 160.0]},
 {1: [102.0, 152.0, 112.0, 162.0]}]

# %%
a[0][1]
# Out:
# [100.0, 150.0, 110.0, 160.0]

# %%
import cv2
import numpy as np
import sys
sys.path.append('../')
import constants
from utils import ( convert_pixel_distance_to_meters , 
                   convert_meters_to_pixel_distance , 
                   get_foot_position , 
                   get_closest_keypoint_index ,
                   get_height_of_bbox , 
                   measure_xy_distance ,
                   get_center_of_bbox ,
                   measure_distance)

# %%
from utils import (read_video, save_video)
from trackers import PlayerTracker , BallTracker
from court_line_detector import CourtLineDetector
from mini_court import MiniCourt
import cv2 

player_tracker = PlayerTracker(model_path="yolov8x")
ball_tracker = BallTracker(model_path="models/yolo5_best.pt")

input_video_path = 'input_videos/input_video.mp4'
video_frames = read_video(input_video_path)

court_model_path = "models/keypoints_model.pth"
court_line_detector = CourtLineDetector(court_model_path)
court_keypoints = court_line_detector.predict(video_frames[0])



player_detections = player_tracker.detect_frames(video_frames , read_from_stub=True , 
                                                     stub_path="tracker_stubs/player_detections.pkl")
    
ball_detections = ball_tracker.detect_frames(video_frames , read_from_stub=True , 
                                                     stub_path="tracker_stubs/ball_detections.pkl")

player_detections = player_tracker.choose_and_filter_players(court_keypoints ,player_detections)
ball_detections = ball_tracker.interpolate_ball_positions(ball_detections)
print("player_detections",player_detections[0])
print("ball_detections",ball_detections[0])

player_heights = {
            1: constants.PLAYER_1_HEIGHT_METERS,
            2: constants.PLAYER_2_HEIGHT_METERS
        }
output_player_boxes = []
output_ball_boxes = []

for frame_num , player_bbox in enumerate(player_detections):
        print('frame_num' , frame_num)
        print('player key', player_bbox.keys())
        ball_box = ball_detections[frame_num][1]
        ball_position = get_center_of_bbox(ball_box)
        print('ball_position' , ball_position)
        closest_player_id_to_ball = min(player_bbox.keys(), key=lambda x: measure_distance(ball_position, get_center_of_bbox(player_bbox[x]))) # anonymous function that takes x (which is the player ID, 1 or 2) as an argument and return the id that have the min distance
        print("closest_player_id_to_ball",closest_player_id_to_ball)

        output_player_bboxes_dict = {}
        for player_id , bbox in player_bbox.items():
            foot_position = get_foot_position(bbox)

            # get the cloesest keypoint index
            closest_key_point_index = get_closest_keypoint_index(foot_position, court_keypoints , [0,2,12,13])
            print("closest_key_point_index",closest_key_point_index)
            
            closest_key_point = (court_keypoints[closest_key_point_index*2], 
                                     court_keypoints[closest_key_point_index*2+1])

                # Get Player height in pixels
            frame_index_min = max(0, frame_num-20)
            frame_index_max = min(len(player_detections), frame_num+50)
            bboxes_heights_in_pixels = [get_height_of_bbox(player_detections[i][player_id]) for i in range (frame_index_min,frame_index_max)]
# Out:
# c:\Users\RTC\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\RTC\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# player_detections {1: [480.2823486328125, 751.5975341796875, 624.8380126953125, 930.6015625], 2: [1030.5684814453125, 201.68310546875, 1095.9012451171875, 308.51904296875]}
# ball_detections {1: [892.924560546875, 616.61474609375, 911.2674560546875, 636.578369140625]}
# frame_num 0
# player key dict_keys([1, 2])
# ball_position (902, 626)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 1
# player key dict_keys([1, 2])
# ball_position (902, 626)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 2
# player key dict_keys([1, 2])
# ball_position (887, 640)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 3
# player key dict_keys([1, 2])
# ball_position (873, 654)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 4
# player key dict_keys([1, 2])
# ball_position (858, 668)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 5
# player key dict_keys([1, 2])
# ball_position (844, 682)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 6
# player key dict_keys([1, 2])
# ball_position (829, 696)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 7
# player key dict_keys([1, 2])
# ball_position (822, 705)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 8
# player key dict_keys([1, 2])
# ball_position (805, 728)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 9
# player key dict_keys([1, 2])
# ball_position (788, 753)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 10
# player key dict_keys([1, 2])
# ball_position (780, 767)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 11
# player key dict_keys([1, 2])
# ball_position (786, 728)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 12
# player key dict_keys([1, 2])
# ball_position (795, 692)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 13
# player key dict_keys([1, 2])
# ball_position (804, 657)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 14
# player key dict_keys([1, 2])
# ball_position (812, 617)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 15
# player key dict_keys([1, 2])
# ball_position (823, 578)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 16
# player key dict_keys([1, 2])
# ball_position (828, 560)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 17
# player key dict_keys([1, 2])
# ball_position (835, 530)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 18
# player key dict_keys([1, 2])
# ball_position (845, 501)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 19
# player key dict_keys([1, 2])
# ball_position (850, 482)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 20
# player key dict_keys([1, 2])
# ball_position (855, 463)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 21
# player key dict_keys([1, 2])
# ball_position (860, 445)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 22
# player key dict_keys([1, 2])
# ball_position (865, 426)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 23
# player key dict_keys([1, 2])
# ball_position (870, 408)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 24
# player key dict_keys([1, 2])
# ball_position (875, 397)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 25
# player key dict_keys([1, 2])
# ball_position (879, 386)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 26
# player key dict_keys([1, 2])
# ball_position (883, 374)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 27
# player key dict_keys([1, 2])
# ball_position (888, 363)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 28
# player key dict_keys([1, 2])
# ball_position (892, 352)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 29
# player key dict_keys([1, 2])
# ball_position (897, 340)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 30
# player key dict_keys([1, 2])
# ball_position (900, 332)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 31
# player key dict_keys([1, 2])
# ball_position (904, 328)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 32
# player key dict_keys([1, 2])
# ball_position (907, 323)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 33
# player key dict_keys([1, 2])
# ball_position (911, 319)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 34
# player key dict_keys([1, 2])
# ball_position (914, 315)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 35
# player key dict_keys([1, 2])
# ball_position (918, 311)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 36
# player key dict_keys([1, 2])
# ball_position (920, 308)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 37
# player key dict_keys([1, 2])
# ball_position (921, 307)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 38
# player key dict_keys([1, 2])
# ball_position (924, 306)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 39
# player key dict_keys([1, 2])
# ball_position (927, 306)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 40
# player key dict_keys([1, 2])
# ball_position (928, 307)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 41
# player key dict_keys([1, 2])
# ball_position (931, 309)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 42
# player key dict_keys([1, 2])
# ball_position (934, 311)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 43
# player key dict_keys([1, 2])
# ball_position (936, 313)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 44
# player key dict_keys([1, 2])
# ball_position (939, 315)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 45
# player key dict_keys([1, 2])
# ball_position (941, 317)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 46
# player key dict_keys([1, 2])
# ball_position (943, 311)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 47
# player key dict_keys([1, 2])
# ball_position (944, 304)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 48
# player key dict_keys([1, 2])
# ball_position (945, 297)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 49
# player key dict_keys([1, 2])
# ball_position (946, 290)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 50
# player key dict_keys([1, 2])
# ball_position (947, 284)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 51
# player key dict_keys([1, 2])
# ball_position (949, 272)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 52
# player key dict_keys([1, 2])
# ball_position (949, 266)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 53
# player key dict_keys([1, 2])
# ball_position (949, 256)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 54
# player key dict_keys([1, 2])
# ball_position (950, 245)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 55
# player key dict_keys([1, 2])
# ball_position (951, 241)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 56
# player key dict_keys([1, 2])
# ball_position (949, 237)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 57
# player key dict_keys([1, 2])
# ball_position (940, 242)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 58
# player key dict_keys([1, 2])
# ball_position (931, 247)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 59
# player key dict_keys([1, 2])
# ball_position (923, 252)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 60
# player key dict_keys([1, 2])
# ball_position (914, 257)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 61
# player key dict_keys([1, 2])
# ball_position (905, 263)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 62
# player key dict_keys([1, 2])
# ball_position (897, 273)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 63
# player key dict_keys([1, 2])
# ball_position (888, 283)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 64
# player key dict_keys([1, 2])
# ball_position (880, 293)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 65
# player key dict_keys([1, 2])
# ball_position (869, 310)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 66
# player key dict_keys([1, 2])
# ball_position (857, 328)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 67
# player key dict_keys([1, 2])
# ball_position (852, 337)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 68
# player key dict_keys([1, 2])
# ball_position (842, 359)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 69
# player key dict_keys([1, 2])
# ball_position (831, 381)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 70
# player key dict_keys([1, 2])
# ball_position (822, 406)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 71
# player key dict_keys([1, 2])
# ball_position (812, 432)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 72
# player key dict_keys([1, 2])
# ball_position (803, 457)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 73
# player key dict_keys([1, 2])
# ball_position (794, 483)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 74
# player key dict_keys([1, 2])
# ball_position (784, 508)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 75
# player key dict_keys([1, 2])
# ball_position (775, 534)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 76
# player key dict_keys([1, 2])
# ball_position (766, 562)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 77
# player key dict_keys([1, 2])
# ball_position (757, 591)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 78
# player key dict_keys([1, 2])
# ball_position (747, 628)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 79
# player key dict_keys([1, 2])
# ball_position (740, 650)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 80
# player key dict_keys([1, 2])
# ball_position (729, 694)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 81
# player key dict_keys([1, 2])
# ball_position (722, 700)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 82
# player key dict_keys([1, 2])
# ball_position (714, 705)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 83
# player key dict_keys([1, 2])
# ball_position (707, 711)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 84
# player key dict_keys([1, 2])
# ball_position (700, 716)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 85
# player key dict_keys([1, 2])
# ball_position (692, 722)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 86
# player key dict_keys([1, 2])
# ball_position (685, 728)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 87
# player key dict_keys([1, 2])
# ball_position (678, 733)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 88
# player key dict_keys([1, 2])
# ball_position (670, 739)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 89
# player key dict_keys([1, 2])
# ball_position (663, 745)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 90
# player key dict_keys([1, 2])
# ball_position (656, 754)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 91
# player key dict_keys([1, 2])
# ball_position (649, 763)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 92
# player key dict_keys([1, 2])
# ball_position (641, 772)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 93
# player key dict_keys([1, 2])
# ball_position (633, 786)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 94
# player key dict_keys([1, 2])
# ball_position (629, 796)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 95
# player key dict_keys([1, 2])
# ball_position (632, 758)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 96
# player key dict_keys([1, 2])
# ball_position (635, 720)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 97
# player key dict_keys([1, 2])
# ball_position (639, 694)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 98
# player key dict_keys([1, 2])
# ball_position (646, 645)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 99
# player key dict_keys([1, 2])
# ball_position (653, 596)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 100
# player key dict_keys([1, 2])
# ball_position (656, 575)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 101
# player key dict_keys([1, 2])
# ball_position (660, 542)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 102
# player key dict_keys([1, 2])
# ball_position (664, 509)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 103
# player key dict_keys([1, 2])
# ball_position (667, 491)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 104
# player key dict_keys([1, 2])
# ball_position (669, 473)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 105
# player key dict_keys([1, 2])
# ball_position (672, 455)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 106
# player key dict_keys([1, 2])
# ball_position (674, 438)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 107
# player key dict_keys([1, 2])
# ball_position (677, 420)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 108
# player key dict_keys([1, 2])
# ball_position (679, 402)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 109
# player key dict_keys([1, 2])
# ball_position (681, 394)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 110
# player key dict_keys([1, 2])
# ball_position (682, 387)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 111
# player key dict_keys([1, 2])
# ball_position (683, 379)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 112
# player key dict_keys([1, 2])
# ball_position (685, 371)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 113
# player key dict_keys([1, 2])
# ball_position (686, 363)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 114
# player key dict_keys([1, 2])
# ball_position (687, 358)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 115
# player key dict_keys([1, 2])
# ball_position (687, 356)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 116
# player key dict_keys([1, 2])
# ball_position (687, 354)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 117
# player key dict_keys([1, 2])
# ball_position (687, 354)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 118
# player key dict_keys([1, 2])
# ball_position (687, 341)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 119
# player key dict_keys([1, 2])
# ball_position (688, 329)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 120
# player key dict_keys([1, 2])
# ball_position (688, 314)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 121
# player key dict_keys([1, 2])
# ball_position (688, 298)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 122
# player key dict_keys([1, 2])
# ball_position (688, 283)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 123
# player key dict_keys([1, 2])
# ball_position (688, 268)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 124
# player key dict_keys([1, 2])
# ball_position (689, 262)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 125
# player key dict_keys([1, 2])
# ball_position (689, 251)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 126
# player key dict_keys([1, 2])
# ball_position (689, 239)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 127
# player key dict_keys([1, 2])
# ball_position (689, 235)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 128
# player key dict_keys([1, 2])
# ball_position (697, 235)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 129
# player key dict_keys([1, 2])
# ball_position (706, 235)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 130
# player key dict_keys([1, 2])
# ball_position (714, 235)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 131
# player key dict_keys([1, 2])
# ball_position (723, 235)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 132
# player key dict_keys([1, 2])
# ball_position (731, 236)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 133
# player key dict_keys([1, 2])
# ball_position (739, 236)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 134
# player key dict_keys([1, 2])
# ball_position (748, 236)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 135
# player key dict_keys([1, 2])
# ball_position (756, 236)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 136
# player key dict_keys([1, 2])
# ball_position (761, 238)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 137
# player key dict_keys([1, 2])
# ball_position (775, 244)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 138
# player key dict_keys([1, 2])
# ball_position (786, 249)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 139
# player key dict_keys([1, 2])
# ball_position (796, 254)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 140
# player key dict_keys([1, 2])
# ball_position (807, 258)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 141
# player key dict_keys([1, 2])
# ball_position (816, 264)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 142
# player key dict_keys([1, 2])
# ball_position (826, 270)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 143
# player key dict_keys([1, 2])
# ball_position (839, 280)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 144
# player key dict_keys([1, 2])
# ball_position (852, 289)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 145
# player key dict_keys([1, 2])
# ball_position (858, 293)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 146
# player key dict_keys([1, 2])
# ball_position (874, 307)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 147
# player key dict_keys([1, 2])
# ball_position (885, 317)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 148
# player key dict_keys([1, 2])
# ball_position (895, 327)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 149
# player key dict_keys([1, 2])
# ball_position (906, 336)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 150
# player key dict_keys([1, 2])
# ball_position (922, 352)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 151
# player key dict_keys([1, 2])
# ball_position (928, 359)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 152
# player key dict_keys([1, 2])
# ball_position (943, 376)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 153
# player key dict_keys([1, 2])
# ball_position (955, 389)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 154
# player key dict_keys([1, 2])
# ball_position (967, 401)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 155
# player key dict_keys([1, 2])
# ball_position (981, 420)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 156
# player key dict_keys([1, 2])
# ball_position (994, 438)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 157
# player key dict_keys([1, 2])
# ball_position (1008, 457)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 158
# player key dict_keys([1, 2])
# ball_position (1021, 475)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 159
# player key dict_keys([1, 2])
# ball_position (1034, 494)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 160
# player key dict_keys([1, 2])
# ball_position (1048, 512)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 161
# player key dict_keys([1, 2])
# ball_position (1061, 531)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 162
# player key dict_keys([1, 2])
# ball_position (1076, 556)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 163
# player key dict_keys([1, 2])
# ball_position (1085, 570)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 164
# player key dict_keys([1, 2])
# ball_position (1102, 598)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 165
# player key dict_keys([1, 2])
# ball_position (1119, 626)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 166
# player key dict_keys([1, 2])
# ball_position (1130, 634)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 167
# player key dict_keys([1, 2])
# ball_position (1141, 641)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 168
# player key dict_keys([1, 2])
# ball_position (1152, 648)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 169
# player key dict_keys([1, 2])
# ball_position (1164, 656)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 170
# player key dict_keys([1, 2])
# ball_position (1175, 663)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 171
# player key dict_keys([1, 2])
# ball_position (1186, 670)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 172
# player key dict_keys([1, 2])
# ball_position (1197, 678)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 173
# player key dict_keys([1, 2])
# ball_position (1208, 685)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 174
# player key dict_keys([1, 2])
# ball_position (1219, 693)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 175
# player key dict_keys([1, 2])
# ball_position (1231, 700)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 176
# player key dict_keys([1, 2])
# ball_position (1242, 707)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 177
# player key dict_keys([1, 2])
# ball_position (1253, 715)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 178
# player key dict_keys([1, 2])
# ball_position (1264, 722)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 179
# player key dict_keys([1, 2])
# ball_position (1275, 729)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 180
# player key dict_keys([1, 2])
# ball_position (1286, 737)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 181
# player key dict_keys([1, 2])
# ball_position (1295, 743)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 182
# player key dict_keys([1, 2])
# ball_position (1304, 748)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 183
# player key dict_keys([1, 2])
# ball_position (1299, 705)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 184
# player key dict_keys([1, 2])
# ball_position (1293, 661)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 185
# player key dict_keys([1, 2])
# ball_position (1288, 618)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 186
# player key dict_keys([1, 2])
# ball_position (1280, 570)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 187
# player key dict_keys([1, 2])
# ball_position (1277, 548)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 188
# player key dict_keys([1, 2])
# ball_position (1272, 527)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 189
# player key dict_keys([1, 2])
# ball_position (1267, 506)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 190
# player key dict_keys([1, 2])
# ball_position (1261, 484)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 191
# player key dict_keys([1, 2])
# ball_position (1256, 463)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 192
# player key dict_keys([1, 2])
# ball_position (1250, 442)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 193
# player key dict_keys([1, 2])
# ball_position (1245, 421)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 194
# player key dict_keys([1, 2])
# ball_position (1240, 399)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 195
# player key dict_keys([1, 2])
# ball_position (1234, 378)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 196
# player key dict_keys([1, 2])
# ball_position (1231, 370)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 197
# player key dict_keys([1, 2])
# ball_position (1228, 362)
# closest_player_id_to_ball 1
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 198
# player key dict_keys([1, 2])
# ball_position (1225, 354)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 199
# player key dict_keys([1, 2])
# ball_position (1222, 345)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 200
# player key dict_keys([1, 2])
# ball_position (1218, 337)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 201
# player key dict_keys([1, 2])
# ball_position (1215, 329)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 202
# player key dict_keys([1, 2])
# ball_position (1212, 321)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 203
# player key dict_keys([1, 2])
# ball_position (1209, 313)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 204
# player key dict_keys([1, 2])
# ball_position (1206, 304)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 205
# player key dict_keys([1, 2])
# ball_position (1202, 296)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 206
# player key dict_keys([1, 2])
# ball_position (1199, 288)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 207
# player key dict_keys([1, 2])
# ball_position (1196, 280)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 208
# player key dict_keys([1, 2])
# ball_position (1193, 271)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 209
# player key dict_keys([1, 2])
# ball_position (1192, 256)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 210
# player key dict_keys([1, 2])
# ball_position (1190, 239)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 211
# player key dict_keys([1, 2])
# ball_position (1189, 233)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 212
# player key dict_keys([1, 2])
# ball_position (1188, 221)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0
# frame_num 213
# player key dict_keys([1, 2])
# ball_position (1187, 211)
# closest_player_id_to_ball 2
# closest_key_point_index 2
# closest_key_point_index 0

# %%
len(player_detections)
# Out:
# 214
